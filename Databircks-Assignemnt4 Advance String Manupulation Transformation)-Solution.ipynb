# %% [markdown]
# <span style="color:orange">
#  <h2> Databircks-Assignemnt 4: Advance String Manupulation Transformation)
# </span>
#   <h5>
#     <span style="color:red">
# <b>Author: Deepak Goyal <br>
#    <a> adeus.azurelib.com </a><br>
#    Email at: admin@azurelib.com
# </span>

# %% [markdown]
# <b> What is the abbreviated version of each employee's last name, with the first letter and the two following letters included?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import *
df = spark.read.csv('dbfs:/FileStore/EmployeeData_fWRqkJfIxK.csv',header=True,inferSchema=True)
df.withColumn('Abb_last_name', substring(df.last_name,1,3)).show()
# Out:
# +---+----------+---------+--------------------+------+------+-------------------+--------+-------------+
# | id|first_name|last_name|               email|gender|salary|       creationDate|   bonus|Abb_last_name|
# +---+----------+---------+--------------------+------+------+-------------------+--------+-------------+
# |  1|    Valene|   Ingley|vingley0@livejour...|Female| 44104|1957-09-09 16:44:40|    null|          Ing|
# |  2|  Lynnelle|    Hurll| lhurll1@answers.com|Female|112411|1907-05-10 17:38:56|    null|          Hur|
# |  3|   Miranda|    Train|   mtrain2@imgur.com|Female| 91073|1941-01-24 16:05:23|12875.54|          Tra|
# |  4|    Dulsea|     Foss|dfoss3@dagondesig...|Female|193291|1942-05-09 20:59:39|    null|          Fos|
# |  5|    Anatol|  Dunklee| adunklee4@google.de|  Male| 22175|1950-07-26 16:28:00| 1432.12|          Dun|
# |  6|     Baily|   Antony| bantony5@sfgate.com|  Male|127337|1913-10-14 11:25:33|    null|          Ant|
# |  7|    Eunice|   Cardus|ecardus6@scientif...|Female|136574|1901-11-02 15:09:47|38676.94|          Car|
# |  8|  Aubrette|  Lippett| alippett7@nifty.com|Female|165713|1919-12-16 08:20:42|60150.66|          Lip|
# |  9|   Sibylla|Sickamore|ssickamore8@faceb...|Female|107243|2020-03-15 15:00:30|    null|          Sic|
# | 10|      null|   Altree|paltree9@dropbox.com|Female|197594|1975-06-21 23:27:12|72533.37|          Alt|
# | 11|      Coop|    Richt|   crichta@sogou.com|  Male| 19964|1939-02-13 16:18:24|56973.41|          Ric|
# | 12|  Giuseppe|  Scimoni|gscimonib@craigsl...|  Male|176531|1967-04-06 07:23:03|    null|          Sci|
# | 13|    Lovell|  Iorizzo|liorizzoc@cpanel.net|  Male|189150|1949-06-06 16:25:20| 41474.8|          Ior|
# | 14|       Deb|    Mogra|   dmograd@bbc.co.uk|Female|197829|1997-07-27 14:55:52|46528.57|          Mog|
# | 15|  Hastings| Jelliman|hjellimane@histat...|  Male|179296|1915-07-05 07:02:06|80194.64|          Jel|
# | 16|     Josee|   Burnep|    jburnepf@php.net|  null| 78569|1923-11-08 20:59:14|88925.13|          Bur|
# | 17|     Gilly|   Fownes|gfownesg@redcross...|Female|  2527|1946-07-30 21:10:57|    null|          Fow|
# | 18|      null|Schruyers|lschruyersh@desde...|  Male|109936|1979-06-16 01:12:48|37243.09|          Sch|
# | 19|     Maris|Chatelain| mchatelaini@unc.edu|Female|190047|2008-01-11 17:16:21|76469.65|          Cha|
# | 20|    Casper|  Aughtie|    caughtiej@vk.com|  Male| 38689|1982-04-06 05:13:49| 80404.8|          Aug|
# +---+----------+---------+--------------------+------+------+-------------------+--------+-------------+
# only showing top 20 rows

# %% [markdown]
# d
# <b> What is the domain name of each employee's email address, so that their emails can be filtered and routed to the correct department?

# %%
# Write your code using the Spark Function
df.withColumn('Domain_name',split(df.email,'@')[1]).show()
# Out:
# +---+----------+---------+--------------------+------+------+-------------------+--------+--------------------+
# | id|first_name|last_name|               email|gender|salary|       creationDate|   bonus|         Domain_name|
# +---+----------+---------+--------------------+------+------+-------------------+--------+--------------------+
# |  1|    Valene|   Ingley|vingley0@livejour...|Female| 44104|1957-09-09 16:44:40|    null|     livejournal.com|
# |  2|  Lynnelle|    Hurll| lhurll1@answers.com|Female|112411|1907-05-10 17:38:56|    null|         answers.com|
# |  3|   Miranda|    Train|   mtrain2@imgur.com|Female| 91073|1941-01-24 16:05:23|12875.54|           imgur.com|
# |  4|    Dulsea|     Foss|dfoss3@dagondesig...|Female|193291|1942-05-09 20:59:39|    null|     dagondesign.com|
# |  5|    Anatol|  Dunklee| adunklee4@google.de|  Male| 22175|1950-07-26 16:28:00| 1432.12|           google.de|
# |  6|     Baily|   Antony| bantony5@sfgate.com|  Male|127337|1913-10-14 11:25:33|    null|          sfgate.com|
# |  7|    Eunice|   Cardus|ecardus6@scientif...|Female|136574|1901-11-02 15:09:47|38676.94|scientificamerica...|
# |  8|  Aubrette|  Lippett| alippett7@nifty.com|Female|165713|1919-12-16 08:20:42|60150.66|           nifty.com|
# |  9|   Sibylla|Sickamore|ssickamore8@faceb...|Female|107243|2020-03-15 15:00:30|    null|        facebook.com|
# | 10|      null|   Altree|paltree9@dropbox.com|Female|197594|1975-06-21 23:27:12|72533.37|         dropbox.com|
# | 11|      Coop|    Richt|   crichta@sogou.com|  Male| 19964|1939-02-13 16:18:24|56973.41|           sogou.com|
# | 12|  Giuseppe|  Scimoni|gscimonib@craigsl...|  Male|176531|1967-04-06 07:23:03|    null|      craigslist.org|
# | 13|    Lovell|  Iorizzo|liorizzoc@cpanel.net|  Male|189150|1949-06-06 16:25:20| 41474.8|          cpanel.net|
# | 14|       Deb|    Mogra|   dmograd@bbc.co.uk|Female|197829|1997-07-27 14:55:52|46528.57|           bbc.co.uk|
# | 15|  Hastings| Jelliman|hjellimane@histat...|  Male|179296|1915-07-05 07:02:06|80194.64|         histats.com|
# | 16|     Josee|   Burnep|    jburnepf@php.net|  null| 78569|1923-11-08 20:59:14|88925.13|             php.net|
# | 17|     Gilly|   Fownes|gfownesg@redcross...|Female|  2527|1946-07-30 21:10:57|    null|        redcross.org|
# | 18|      null|Schruyers|lschruyersh@desde...|  Male|109936|1979-06-16 01:12:48|37243.09|           desdev.cn|
# | 19|     Maris|Chatelain| mchatelaini@unc.edu|Female|190047|2008-01-11 17:16:21|76469.65|             unc.edu|
# | 20|    Casper|  Aughtie|    caughtiej@vk.com|  Male| 38689|1982-04-06 05:13:49| 80404.8|              vk.com|
# +---+----------+---------+--------------------+------+------+-------------------+--------+--------------------+
# only showing top 20 rows

# %% [markdown]
# d
# <b> In an effort to protect their privacy, what is each employee's name spelled backwards?

# %%
# Write your code using the Spark Function
df.withColumn('privacy',reverse(concat(df.first_name,df.last_name))).show()
# Out:
# +---+----------+---------+--------------------+------+------+-------------------+--------+----------------+
# | id|first_name|last_name|               email|gender|salary|       creationDate|   bonus|         privacy|
# +---+----------+---------+--------------------+------+------+-------------------+--------+----------------+
# |  1|    Valene|   Ingley|vingley0@livejour...|Female| 44104|1957-09-09 16:44:40|    null|    yelgnIenelaV|
# |  2|  Lynnelle|    Hurll| lhurll1@answers.com|Female|112411|1907-05-10 17:38:56|    null|   llruHellennyL|
# |  3|   Miranda|    Train|   mtrain2@imgur.com|Female| 91073|1941-01-24 16:05:23|12875.54|    niarTadnariM|
# |  4|    Dulsea|     Foss|dfoss3@dagondesig...|Female|193291|1942-05-09 20:59:39|    null|      ssoFaesluD|
# |  5|    Anatol|  Dunklee| adunklee4@google.de|  Male| 22175|1950-07-26 16:28:00| 1432.12|   eelknuDlotanA|
# |  6|     Baily|   Antony| bantony5@sfgate.com|  Male|127337|1913-10-14 11:25:33|    null|     ynotnAyliaB|
# |  7|    Eunice|   Cardus|ecardus6@scientif...|Female|136574|1901-11-02 15:09:47|38676.94|    sudraCecinuE|
# |  8|  Aubrette|  Lippett| alippett7@nifty.com|Female|165713|1919-12-16 08:20:42|60150.66| tteppiLetterbuA|
# |  9|   Sibylla|Sickamore|ssickamore8@faceb...|Female|107243|2020-03-15 15:00:30|    null|eromakciSallybiS|
# | 10|      null|   Altree|paltree9@dropbox.com|Female|197594|1975-06-21 23:27:12|72533.37|            null|
# | 11|      Coop|    Richt|   crichta@sogou.com|  Male| 19964|1939-02-13 16:18:24|56973.41|       thciRpooC|
# | 12|  Giuseppe|  Scimoni|gscimonib@craigsl...|  Male|176531|1967-04-06 07:23:03|    null| inomicSeppesuiG|
# | 13|    Lovell|  Iorizzo|liorizzoc@cpanel.net|  Male|189150|1949-06-06 16:25:20| 41474.8|   ozziroIllevoL|
# | 14|       Deb|    Mogra|   dmograd@bbc.co.uk|Female|197829|1997-07-27 14:55:52|46528.57|        argoMbeD|
# | 15|  Hastings| Jelliman|hjellimane@histat...|  Male|179296|1915-07-05 07:02:06|80194.64|namilleJsgnitsaH|
# | 16|     Josee|   Burnep|    jburnepf@php.net|  null| 78569|1923-11-08 20:59:14|88925.13|     penruBeesoJ|
# | 17|     Gilly|   Fownes|gfownesg@redcross...|Female|  2527|1946-07-30 21:10:57|    null|     senwoFylliG|
# | 18|      null|Schruyers|lschruyersh@desde...|  Male|109936|1979-06-16 01:12:48|37243.09|            null|
# | 19|     Maris|Chatelain| mchatelaini@unc.edu|Female|190047|2008-01-11 17:16:21|76469.65|  nialetahCsiraM|
# | 20|    Casper|  Aughtie|    caughtiej@vk.com|  Male| 38689|1982-04-06 05:13:49| 80404.8|   eithguArepsaC|
# +---+----------+---------+--------------------+------+------+-------------------+--------+----------------+
# only showing top 20 rows

# %% [markdown]
# d
# <b> In order to make their email addresses harder to guess, what is each employee's email address spelled backwards?

# %%
# Write your code using the Spark Function
df.withColumn('reverse_email',reverse(df.email)).show()
# Out:
# +---+----------+---------+--------------------+------+------+-------------------+--------+--------------------+
# | id|first_name|last_name|               email|gender|salary|       creationDate|   bonus|       reverse_email|
# +---+----------+---------+--------------------+------+------+-------------------+--------+--------------------+
# |  1|    Valene|   Ingley|vingley0@livejour...|Female| 44104|1957-09-09 16:44:40|    null|moc.lanruojevil@0...|
# |  2|  Lynnelle|    Hurll| lhurll1@answers.com|Female|112411|1907-05-10 17:38:56|    null| moc.srewsna@1llruhl|
# |  3|   Miranda|    Train|   mtrain2@imgur.com|Female| 91073|1941-01-24 16:05:23|12875.54|   moc.rugmi@2niartm|
# |  4|    Dulsea|     Foss|dfoss3@dagondesig...|Female|193291|1942-05-09 20:59:39|    null|moc.ngisednogad@3...|
# |  5|    Anatol|  Dunklee| adunklee4@google.de|  Male| 22175|1950-07-26 16:28:00| 1432.12| ed.elgoog@4eelknuda|
# |  6|     Baily|   Antony| bantony5@sfgate.com|  Male|127337|1913-10-14 11:25:33|    null| moc.etagfs@5ynotnab|
# |  7|    Eunice|   Cardus|ecardus6@scientif...|Female|136574|1901-11-02 15:09:47|38676.94|moc.naciremacifit...|
# |  8|  Aubrette|  Lippett| alippett7@nifty.com|Female|165713|1919-12-16 08:20:42|60150.66| moc.ytfin@7tteppila|
# |  9|   Sibylla|Sickamore|ssickamore8@faceb...|Female|107243|2020-03-15 15:00:30|    null|moc.koobecaf@8ero...|
# | 10|      null|   Altree|paltree9@dropbox.com|Female|197594|1975-06-21 23:27:12|72533.37|moc.xobpord@9eertlap|
# | 11|      Coop|    Richt|   crichta@sogou.com|  Male| 19964|1939-02-13 16:18:24|56973.41|   moc.uogos@athcirc|
# | 12|  Giuseppe|  Scimoni|gscimonib@craigsl...|  Male|176531|1967-04-06 07:23:03|    null|gro.tsilsgiarc@bi...|
# | 13|    Lovell|  Iorizzo|liorizzoc@cpanel.net|  Male|189150|1949-06-06 16:25:20| 41474.8|ten.lenapc@cozziroil|
# | 14|       Deb|    Mogra|   dmograd@bbc.co.uk|Female|197829|1997-07-27 14:55:52|46528.57|   ku.oc.cbb@dargomd|
# | 15|  Hastings| Jelliman|hjellimane@histat...|  Male|179296|1915-07-05 07:02:06|80194.64|moc.statsih@enami...|
# | 16|     Josee|   Burnep|    jburnepf@php.net|  null| 78569|1923-11-08 20:59:14|88925.13|    ten.php@fpenrubj|
# | 17|     Gilly|   Fownes|gfownesg@redcross...|Female|  2527|1946-07-30 21:10:57|    null|gro.ssorcder@gsen...|
# | 18|      null|Schruyers|lschruyersh@desde...|  Male|109936|1979-06-16 01:12:48|37243.09|nc.vedsed@hsreyur...|
# | 19|     Maris|Chatelain| mchatelaini@unc.edu|Female|190047|2008-01-11 17:16:21|76469.65| ude.cnu@inialetahcm|
# | 20|    Casper|  Aughtie|    caughtiej@vk.com|  Male| 38689|1982-04-06 05:13:49| 80404.8|    moc.kv@jeithguac|
# +---+----------+---------+--------------------+------+------+-------------------+--------+--------------------+
# only showing top 20 rows

# %% [markdown]
# d
# <b> What is each employee's first name, repeated twice, to improve personalization of emails and messages?

# %%
# Write your code using the Spark Function
#df.withColumn('first_name_repeated',repeat(df.first_name,2)).show()
df.withColumn('first_name_repeated',concat_ws(' ',df.first_name,df.first_name)).show()
# Out:
# +---+----------+---------+--------------------+------+------+-------------------+--------+-------------------+
# | id|first_name|last_name|               email|gender|salary|       creationDate|   bonus|first_name_repeated|
# +---+----------+---------+--------------------+------+------+-------------------+--------+-------------------+
# |  1|    Valene|   Ingley|vingley0@livejour...|Female| 44104|1957-09-09 16:44:40|    null|      Valene Valene|
# |  2|  Lynnelle|    Hurll| lhurll1@answers.com|Female|112411|1907-05-10 17:38:56|    null|  Lynnelle Lynnelle|
# |  3|   Miranda|    Train|   mtrain2@imgur.com|Female| 91073|1941-01-24 16:05:23|12875.54|    Miranda Miranda|
# |  4|    Dulsea|     Foss|dfoss3@dagondesig...|Female|193291|1942-05-09 20:59:39|    null|      Dulsea Dulsea|
# |  5|    Anatol|  Dunklee| adunklee4@google.de|  Male| 22175|1950-07-26 16:28:00| 1432.12|      Anatol Anatol|
# |  6|     Baily|   Antony| bantony5@sfgate.com|  Male|127337|1913-10-14 11:25:33|    null|        Baily Baily|
# |  7|    Eunice|   Cardus|ecardus6@scientif...|Female|136574|1901-11-02 15:09:47|38676.94|      Eunice Eunice|
# |  8|  Aubrette|  Lippett| alippett7@nifty.com|Female|165713|1919-12-16 08:20:42|60150.66|  Aubrette Aubrette|
# |  9|   Sibylla|Sickamore|ssickamore8@faceb...|Female|107243|2020-03-15 15:00:30|    null|    Sibylla Sibylla|
# | 10|      null|   Altree|paltree9@dropbox.com|Female|197594|1975-06-21 23:27:12|72533.37|                   |
# | 11|      Coop|    Richt|   crichta@sogou.com|  Male| 19964|1939-02-13 16:18:24|56973.41|          Coop Coop|
# | 12|  Giuseppe|  Scimoni|gscimonib@craigsl...|  Male|176531|1967-04-06 07:23:03|    null|  Giuseppe Giuseppe|
# | 13|    Lovell|  Iorizzo|liorizzoc@cpanel.net|  Male|189150|1949-06-06 16:25:20| 41474.8|      Lovell Lovell|
# | 14|       Deb|    Mogra|   dmograd@bbc.co.uk|Female|197829|1997-07-27 14:55:52|46528.57|            Deb Deb|
# | 15|  Hastings| Jelliman|hjellimane@histat...|  Male|179296|1915-07-05 07:02:06|80194.64|  Hastings Hastings|
# | 16|     Josee|   Burnep|    jburnepf@php.net|  null| 78569|1923-11-08 20:59:14|88925.13|        Josee Josee|
# | 17|     Gilly|   Fownes|gfownesg@redcross...|Female|  2527|1946-07-30 21:10:57|    null|        Gilly Gilly|
# | 18|      null|Schruyers|lschruyersh@desde...|  Male|109936|1979-06-16 01:12:48|37243.09|                   |
# | 19|     Maris|Chatelain| mchatelaini@unc.edu|Female|190047|2008-01-11 17:16:21|76469.65|        Maris Maris|
# | 20|    Casper|  Aughtie|    caughtiej@vk.com|  Male| 38689|1982-04-06 05:13:49| 80404.8|      Casper Casper|
# +---+----------+---------+--------------------+------+------+-------------------+--------+-------------------+
# only showing top 20 rows

# %% [markdown]
# d
# <b> What is the country code of each employee's email domain, which can help identify global market opportunities?

# %%
# Write your code using the Spark Function
df2 = df.withColumn('domain',element_at(split(df.email,'\.'),-1)).show()
#column is an array that's why element_at returns an array
# Out:
# +---+----------+---------+--------------------+------+------+-------------------+--------+------+
# | id|first_name|last_name|               email|gender|salary|       creationDate|   bonus|domain|
# +---+----------+---------+--------------------+------+------+-------------------+--------+------+
# |  1|    Valene|   Ingley|vingley0@livejour...|Female| 44104|1957-09-09 16:44:40|    null|   com|
# |  2|  Lynnelle|    Hurll| lhurll1@answers.com|Female|112411|1907-05-10 17:38:56|    null|   com|
# |  3|   Miranda|    Train|   mtrain2@imgur.com|Female| 91073|1941-01-24 16:05:23|12875.54|   com|
# |  4|    Dulsea|     Foss|dfoss3@dagondesig...|Female|193291|1942-05-09 20:59:39|    null|   com|
# |  5|    Anatol|  Dunklee| adunklee4@google.de|  Male| 22175|1950-07-26 16:28:00| 1432.12|    de|
# |  6|     Baily|   Antony| bantony5@sfgate.com|  Male|127337|1913-10-14 11:25:33|    null|   com|
# |  7|    Eunice|   Cardus|ecardus6@scientif...|Female|136574|1901-11-02 15:09:47|38676.94|   com|
# |  8|  Aubrette|  Lippett| alippett7@nifty.com|Female|165713|1919-12-16 08:20:42|60150.66|   com|
# |  9|   Sibylla|Sickamore|ssickamore8@faceb...|Female|107243|2020-03-15 15:00:30|    null|   com|
# | 10|      null|   Altree|paltree9@dropbox.com|Female|197594|1975-06-21 23:27:12|72533.37|   com|
# | 11|      Coop|    Richt|   crichta@sogou.com|  Male| 19964|1939-02-13 16:18:24|56973.41|   com|
# | 12|  Giuseppe|  Scimoni|gscimonib@craigsl...|  Male|176531|1967-04-06 07:23:03|    null|   org|
# | 13|    Lovell|  Iorizzo|liorizzoc@cpanel.net|  Male|189150|1949-06-06 16:25:20| 41474.8|   net|
# | 14|       Deb|    Mogra|   dmograd@bbc.co.uk|Female|197829|1997-07-27 14:55:52|46528.57|    uk|
# | 15|  Hastings| Jelliman|hjellimane@histat...|  Male|179296|1915-07-05 07:02:06|80194.64|   com|
# | 16|     Josee|   Burnep|    jburnepf@php.net|  null| 78569|1923-11-08 20:59:14|88925.13|   net|
# | 17|     Gilly|   Fownes|gfownesg@redcross...|Female|  2527|1946-07-30 21:10:57|    null|   org|
# | 18|      null|Schruyers|lschruyersh@desde...|  Male|109936|1979-06-16 01:12:48|37243.09|    cn|
# | 19|     Maris|Chatelain| mchatelaini@unc.edu|Female|190047|2008-01-11 17:16:21|76469.65|   edu|
# | 20|    Casper|  Aughtie|    caughtiej@vk.com|  Male| 38689|1982-04-06 05:13:49| 80404.8|   com|
# +---+----------+---------+--------------------+------+------+-------------------+--------+------+
# only showing top 20 rows

# %% [markdown]
# d
# <b> What is the position of the first occurrence of a dot ('.') character in each employee's email address, which can be used to standardize email addresses in a database?

# %%
# Write your code using the Spark Function
df.withColumn('position_of_.',locate('.',df.email,1)).show()

# %% [markdown]
# d
# <b> What is the full name and email address of each employee, concatenated with a space separator, for use in email communication?

# %%
# Write your code using the Spark Function
df.withColumn('email_updated',concat_ws(' ',df.first_name,df.last_name,df.email)).show()

# %% [markdown]
# d
# <b> What is the first letter of each employee's first name in uppercase, followed by the rest of the name in lowercase, to ensure consistency and proper capitalization?

# %%
# Write your code using the Spark Function
df.withColumn('Capital',concat_ws(' ',initcap(df.first_name),lower(df.last_name))).show()
